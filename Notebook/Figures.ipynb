# %%
library("phyloseq"); packageVersion("phyloseq")
library("ggplot2"); packageVersion("ggplot2")
library("ape"); packageVersion("ape")
library("vegan"); packageVersion("vegan")
library("dplyr"); packageVersion("dplyr")
library("microbiome"); packageVersion("microbiome")
library("tidyverse")
library(ggpubr)
install.packages("svglite")
# Out:
# [1] ‘1.34.0’
# [1] ‘3.3.3’
# [1] ‘5.4.1’
# [1] ‘2.5.7’
# [1] ‘1.0.6’
# [1] ‘1.12.0’
# The downloaded binary packages are in
# 	/var/folders/j4/j37z3nw57wl5490t5t1rhk7h4k4czw/T//Rtmp4By0NA/downloaded_packages

# %%
SV <- t(read.table("/Users/stephanie.rosales/Documents/omics_projects/NutrientsAC16S/trim/exported_AcNu_trim/id-fil4-table-BacArc_AcNu_trimV2.txt",
                   row.names = 1, header = TRUE))
head(SV)
dim(SV)
#removed "#" from first row
map<- read.table("/Users/stephanie.rosales/Documents/omics_projects/NutrientsAC16S/2019_Acer_nutrients/AcNutrients/Nutrient_16s_Metadata.txt",
                 row.names = 1, header = TRUE)
head(map)
dim(map)
## to import taxonomy I had to convert ; into tabs and remove last columns
tax <-as.matrix(read.table("/Users/stephanie.rosales/Documents/omics_projects/NutrientsAC16S//trim/exported_AcNu_trim/taxonomyAcNu_trim.tsv",  
                           row.names = 1, header = FALSE, sep = "\t"))
#head(tax)
colnames(tax) <- c ("Kingdom", "Phylum", "Class", "Order", "Family", "Genus", "Species", "ASV")
tax[tax==""] <- NA
head(tax)
dim(tax)

tree_file <-read_tree("/Users/stephanie.rosales/Documents/omics_projects/NutrientsAC16S//trim/exported_AcNu_trim/tree.nwk")
# Out:
#                 d9a37d86155d9224b0a9331fec4c3504
# AC101JanuaryRY  0
# AC102FebruaryRY 0
# AC102JanuaryRY  0
# AC102MarchRY    0
# AC103DecemberRY 0
# AC104JanuaryRY  0
#                 cab8eef5312f82c2e00ad312974ad6ed
# AC101JanuaryRY  0
# AC102FebruaryRY 0
# AC102JanuaryRY  4
# AC102MarchRY    0
# AC103DecemberRY 0
# AC104JanuaryRY  0
#                 d8ea642fc64ba46b20cf9027953a29f9
# AC101JanuaryRY  0
# AC102FebruaryRY 0
# AC102JanuaryRY  0
# AC102MarchRY    0
# AC103DecemberRY 0
# AC104JanuaryRY  0
#                 1e9cd04a2da65bafb92a7a3224becd2e
# AC101JanuaryRY  0
# AC102FebruaryRY 0
# AC102JanuaryRY  0
# AC102MarchRY    0
# AC103DecemberRY 0
# AC104JanuaryRY  0
#                 636656e4ac93f5a5edfe3104eab2db63
# AC101JanuaryRY  0
# AC102FebruaryRY 0
# AC102JanuaryRY  0
# AC102MarchRY    0
# AC103DecemberRY 0
# AC104JanuaryRY  0
#                 5193b52304263921a5e1dbcc84a1b849
# AC101JanuaryRY  0
# AC102FebruaryRY 0
# AC102JanuaryRY  0
# AC102MarchRY    0
# ...

# %%
ps = phyloseq(otu_table(SV, taxa_are_rows=FALSE), 
               sample_data(map), 
               tax_table(tax),phy_tree(tree_file))
ps

ps = subset_samples(ps, former.id != "105-December-RY" & former.id!="102-December-RY" &
                   former.id !="104-December-RY" &  former.id !="178-January-G" & former.id !="NTC" &
                   former.id !="116-February-GO" & former.id !="126-March-Sick-GO")
ps 


ps = subset_taxa(ps, ASV!="ASV2107")
ps
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 667 taxa and 181 samples ]
# sample_data() Sample Data:       [ 181 samples by 60 sample variables ]
# tax_table()   Taxonomy Table:    [ 667 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 667 tips and 666 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 667 taxa and 179 samples ]
# sample_data() Sample Data:       [ 179 samples by 60 sample variables ]
# tax_table()   Taxonomy Table:    [ 667 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 667 tips and 666 internal nodes ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 666 taxa and 179 samples ]
# sample_data() Sample Data:       [ 179 samples by 60 sample variables ]
# tax_table()   Taxonomy Table:    [ 666 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 666 tips and 665 internal nodes ]

# %%
psr  = transform_sample_counts(ps, function(x) x / sum(x))
psr_melt =psmelt(psr) 
ps_clr <- microbiome::transform(ps, 'clr')

# %%
psr_melt$ExpPhase <- factor(psr_melt$ExpPhase , 
    levels = c("Nutrients", "HeatStress"))

psr_melt$Genotype <- factor(psr_melt$Genotype , 
    levels = c("G_48", "G_62", "G_31", "G_8", "G_7", "G_50"))

supp.labs <- c("Control", "Heat", "Heat")
names(supp.labs) <- c("Nutrients", "HeatStress")

nutr.labs <- c("Ambient", "NH4", "NH4 + P04")
names(nutr.labs) <- c("A", "N", "NP")



#lab1 <- c(expression(Ambient),
 #         expression(NH^4  ), 
  #        expression(NH^4 + PO^4)) 

#names(lab1) <- c("A", "N", "NP")



RA = psr_melt %>%
drop_na(Family) %>%
filter(Abundance > 0.05) %>%
#filter(former.id!="NTC") %>%
ggplot(
       aes(x = Genotype, y=Abundance)) + 
geom_bar(stat="identity", position="stack", aes(fill = Family)) +
scale_fill_manual(values=c("#56B4E9","#CBD588","#5F7FC7", "orange","#DA5724","#CD9BCD",
                           "gray80", "#AD6F3B", "#673770","#006700","#8569D5", 
                           "#5E738F","#D1A33D", "#8A7C64","lightsalmon","aquamarine4", "#652926",
                           "lightblue4", "lightpink","royalblue4","#D14285",
                           "palevioletred1", "#56B4E9","#CBD588","yellow2","ivory4", "#5F7FC7", "orange","#DA5724",
                           "#CD9BCD", "gray80", "darkorchid",
                           "#AD6F3B", "#673770","#D14285", "#652926","#8569D5", "#5E738F")) +

facet_grid(treatment~ExpPhase*Days, space="free", labeller = labeller(treatment =nutr.labs, ExpPhase= supp.labs,
                                                                     label_parsed)) +
guides(fill = guide_legend(keywidth = 0.3, , keyheight =.60, ncol=1)) +
theme_classic() +
theme(legend.text =element_text(size=4)) +
theme(legend.title =element_text(size=4)) +
theme(axis.title.x = element_text(size = 5)) +
theme(axis.title.y = element_text(size = 5)) +
theme(axis.text.y = element_text(size =4)) +
theme(strip.text.x = element_text(size =4)) +
theme(strip.text.y = element_text(size =4)) +
theme(axis.text.x = element_text(angle = 90, hjust = 1, size=3)) +
theme(strip.background = element_rect(
     fill="white", color="black", size=.5)) +
 ylab("Relative abundance")

RA

#ggsave(file="/Users/stephanie.rosales/Documents/omics_projects/NutrientsAC16S/figures/RA_fig.svg", plot=RA, width=10, height=8)


ggsave("/Users/stephanie.rosales/Documents/omics_projects/NutrientsAC16S/figures/RA_fig.svg",
     width = 4, height = 4, units = "in")
# Out:
# plot without title

# %%
sample_data(ps_clr)$ExpPhase <- factor(sample_data(ps_clr)$ExpPhase,
                                    levels = c("Nutrients", "HeatStress"))

head(sample_data(ps_clr)$ExpPhase)


lab1 <- c(expression(Ambient),
          expression(NH[4]  ), 
          expression(NH[4] + PO[4])) 

supp.labs <- c("Control", "Heat")
names(supp.labs) <- c("Nutrients", "HeatStress")


sample_data(ps_clr)$Genotype <- factor(sample_data(ps_clr)$Genotype, 
    levels = c("G_48", "G_62", "G_31", "G_8", "G_7", "G_50"))

ps.ord.clr <- phyloseq::ordinate(ps_clr, "RDA", "euclidean")


sample_data(ps_clr)$Days <- factor(sample_data(ps_clr)$Days,
                                    levels = c("Day75", "Day100", "Day111"))


ord = plot_ordination(ps_clr, ps.ord.clr, color="treatment",
                          shape="Genotype") +
geom_point(size = .01) +
scale_shape_manual("Genotype", values = c(15, 16, 17, 18, 8, 3)) +
theme_classic() +
scale_color_manual("Nutrients", values = c("#4A6CAA", "#469B53" ,"#AA4A74"), labels= lab1) +

facet_grid(.~ExpPhase*Days, labeller = labeller(ExpPhase= supp.labs, label_parsed)) +

theme(legend.text =element_text(size=4)) +
theme(legend.title = element_text(size=5)) +
theme(axis.title.x = element_text(size = 5)) +
theme(axis.title.y = element_text(size = 5)) +
theme(axis.text.x = element_text(size =4)) +
theme(axis.text.y = element_text(size =4)) +
theme(axis.text.y = element_text(size =4)) +
theme(strip.background = element_rect(
     fill="white", color="black", size=.5), strip.text = element_text(size = 5)) +
guides(colour = guide_legend(override.aes = list(size=.5))) +
guides(shape = guide_legend(override.aes = list(size=.5)))
ord 
ggsave("/Users/stephanie.rosales/Documents/omics_projects/NutrientsAC16S/figures/PCA_fig.svg",
     width = 4, height = 4, units = "in", dpi=300)
# Out:
# [1] Nutrients  HeatStress Nutrients  HeatStress Nutrients  Nutrients
# Levels: Nutrients HeatStress
# plot without title

# %%
map$ExpPhase <- factor(map$ExpPhase , 
  levels = c("Nutrients", "HeatStress"))

map$Genotype <- factor(map$Genotype , 
    levels = c("G_48", "G_62", "G_31", "G_8", "G_7", "G_50"))

supp.labs <- c("Heat", "Heat", "Control")
names(supp.labs) <- c("HeatStress", "HeatStress", "Nutrients")

nutr.labs <- c("Ambient", "NH4", "NH4 + P04")
names(nutr.labs) <- c("A", "N", "NP")


rich = map %>%
filter(former.id!="NTC") %>%
ggplot(aes(x = Genotype, y=Richness, fill=Genotype)) + 
geom_boxplot() +
theme_classic() +
facet_grid(treatment~ExpPhase*Days, space="free", labeller = labeller(treatment =nutr.labs, ExpPhase= supp.labs,
                                label_parsed)) +
guides(fill = guide_legend(keywidth = 0.3,keyheight =.60, ncol=1)) +

theme(legend.text =element_text(size=4)) +
theme(legend.title =element_text(size=4)) +
theme(axis.title.x = element_text(size = 5)) +
theme(axis.title.y = element_text(size = 5)) +
theme(axis.text.y = element_text(size =4)) +
theme(strip.text.x = element_text(size =4), strip.background = element_rect(
     fill="white", color="black", size=.5) ) +
theme(strip.text.y = element_text(size =4)) +
theme(axis.text.x = element_text(angle = 90, hjust = 1, size=3)) +
 ylab("Richness") 

rich
# Out:
# Warning message:
# “Removed 7 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
 
map %>%
filter(former.id!="NTC") %>%
ggplot(aes(x = Days, y=Richness, fill=Treatment)) + 
geom_boxplot() +
theme_classic() +
facet_grid(Treatment~., space="free", labeller = labeller(treatment =nutr.labs, ExpPhase= supp.labs,
                                label_parsed)) +
guides(fill = guide_legend(keywidth = 0.3,keyheight =.60, ncol=1)) +

theme(legend.text =element_text(size=4)) +
theme(legend.title =element_text(size=4)) +
theme(axis.title.x = element_text(size = 5)) +
theme(axis.title.y = element_text(size = 5)) +
theme(axis.text.y = element_text(size =4)) +
theme(strip.text.x = element_text(size =4), strip.background = element_rect(
     fill="white", color="black", size=.5) ) +
theme(strip.text.y = element_text(size =4)) +
theme(axis.text.x = element_text(angle = 90, hjust = 1, size=10)) +
 ylab("Richness")
# Out:
# Warning message:
# “Removed 7 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
sig_geno = c("09559efaa02f2d1000b20616d6ac4c10",  
"2a9757272d74d9dceac1fc00fdf9933b")

psr_melt_fil = psr_melt %>%
filter( Treatment =="C") %>%
filter(OTU %in% sig_geno) #%>%
#mutate_if("Order" =="NA", str_replace, "Bacteria", "NA")

# %%
psr_melt_fil$Genotype <- factor(psr_melt_fil$Genotype, 
    levels = c("G_48", "G_62", "G_31", "G_8", "G_7","G_50"))



nutr.labs <- c("Ambient", "N4", "N4 + P04")
names(nutr.labs) <- c("A", "N", "NP")

geno_dif = ggplot(psr_melt_fil, 
       
           aes(x = frag_ID, y=Abundance)) + 
geom_bar(stat="identity", 
         #position="fill", 
         aes(fill =Family)) +
scale_y_continuous(trans = "sqrt") +

scale_fill_manual(values=c("Endozoicomonadaceae" ="grey80", 
                          "Midichloriaceae"= "#006700",
                          "Spirochaetaceae" ="royalblue1"), 
                           na.value = "Navy") +
facet_grid(treatment~Genotype, scales="free_x",
          
           labeller = labeller(treatment =nutr.labs,
                                label_parsed)) +
guides(fill = guide_legend(keywidth = 0.3, , keyheight =.60, ncol=1)) +
theme_classic() +
theme(legend.text =element_text(size=4)) +
theme(legend.title =element_text(size=4)) +
theme(axis.title.x = element_text(size = 5)) +
theme(axis.title.y = element_text(size = 5)) +
theme(axis.text.y = element_text(size =4)) +
theme(strip.text.x = element_text(size =4)) +
theme(strip.text.y = element_text(size =4)) +
theme(strip.background = element_rect(
     fill="white", color="black", size=.5)) +

theme(axis.text.x = element_text(angle = 90, hjust = 1, size=3)) +
 ylab("Relative abundance (sqrt)") +
xlab("Fragment ID")
geno_dif
# Out:
# plot without title

# %%
ggarrange(RA, geno_dif, rich, ord, font.label = list(size = 7, color = "black"), labels=c("A", "B", "C", "D"))
ggsave("/Users/stephanie.rosales/Documents/omics_projects/NutrientsAC16S/figures/fig5.svg",
     width = 6, height = 6, units = "in", dpi=300)
# Out:
# Warning message:
# “Removed 7 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
GoodTaxa = c(
"3f4bf28104659136bd4899d83721746a",
"0172efa347740fe7d9cbd7dec793bd67",
"81fb3f35ca0747aca3f74665829bce3d",
"97f86d082c6b847db4dddb55376e92a6")
allTaxa = taxa_names(psr)
allTaxa <- allTaxa[(allTaxa %in% GoodTaxa)]
sig_psr = prune_taxa(allTaxa, psr)
sig_psr =subset_samples(sig_psr, Days=="Day75")
sig_psr 

melt_ps_treat <- sig_psr %>%
psmelt() #%>% 
#drop_na(Abundance)  %>% 
#filter(Days=="Day_75")
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 4 taxa and 85 samples ]
# sample_data() Sample Data:       [ 85 samples by 60 sample variables ]
# tax_table()   Taxonomy Table:    [ 4 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 4 tips and 3 internal nodes ]

# %%
melt_ps_treat$Genotype <- factor(melt_ps_treat$Genotype , 
    levels = c("G_48", "G_8", "G_62", "G_7", "G_31","G_50"))

ANCOM_nutri=ggplot(melt_ps_treat, aes(x = Treatment, y=Abundance)) + 
#geom_bar(stat="identity", position="fill", aes(fill =Treatment)) +
geom_boxplot(outlier.size=0, aes(fill=Treatment)) +
geom_point(aes(shape=Genotype), alpha=0.5) +
facet_grid(.~Order*Family*Genus, scale="free" ) +
theme_classic() +
scale_y_continuous(trans = "log10") +
theme(legend.position = "bottom", legend.box = "horizontal") +
theme(legend.text =element_text(size=4)) +
theme(legend.title = element_text(size=5)) +
theme(axis.title.x = element_text(size = 5)) +
theme(axis.title.y = element_text(size = 5)) +
theme(axis.text.x = element_text(size =4)) +
#theme(axis.text.y = element_text(size =4)) +
theme(axis.text.x=element_blank()) +
theme(axis.text.y = element_text(size =4)) +
scale_shape_manual("Genotype", values = c(15, 18, 16, 8, 17, 3)) +
theme(strip.background = element_rect(
     fill="white", color="black", size=.5), strip.text = element_text(size = 5)) +
scale_fill_manual(name = "Treatment", labels=c(C=expression(paste(Ambient)),
                               N=expression(paste(NH^4)),
                               NP=expression(NH^4 + PO^4)),
                 values=c("#4A6CAA", "#469B53" ,"#AA4A74")) +
#scale_fill_manual(values=c("#4A6CAA", "#469B53" ,"#AA4A74")) 
ylab("Relative Abundance Log10") +
xlab("Nutrients")

ANCOM_nutri

ggsave("/Users/stephanie.rosales/Documents/omics_projects/NutrientsAC16S/figures/Ancom2_fig.png",
        width = 4.1, height = 4, units = "in", dpi=300)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Removed 246 rows containing non-finite values (stat_boxplot).”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Removed 246 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
psr_C= subset_samples(psr, Days=="Day75" & Treatment=="C")
psr_C
psr_C_melt =  psr_C %>% psmelt
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 666 taxa and 30 samples ]
# sample_data() Sample Data:       [ 30 samples by 60 sample variables ]
# tax_table()   Taxonomy Table:    [ 666 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 666 tips and 665 internal nodes ]

# %%
rick = psr_melt %>%
filter(ASV=="ASV2095")

# %%
rick = psr_C_melt %>%
filter(ASV=="ASV2095") 
summary(lm(Abundance ~ Surivor_110, data=rick))
# Out:
# Call:
# lm(formula = Abundance ~ Surivor_110, data = rick)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.65603 -0.31654  0.02313  0.08910  0.63981
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.33308    0.08675    3.84 0.000645 ***
# Surivor_110  4.04602    0.85719    4.72 5.96e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.3134 on 28 degrees of freedom
# Multiple R-squared:  0.4431,	Adjusted R-squared:  0.4232
# F-statistic: 22.28 on 1 and 28 DF,  p-value: 5.961e-05

# %%
write.table(rick, "/Users//stephanie.rosales/Desktop/rick_allDays.txt", sep="\t")

# %%
spiro = psr_C_melt %>%
filter(ASV=="ASV825") 
summary(lm(Abundance ~ Surivor_110, data=spiro))
# Out:
# Call:
# lm(formula = Abundance ~ Surivor_110, data = spiro)
#
# Residuals:
#        Min         1Q     Median         3Q        Max
# -0.0020392 -0.0005625  0.0000467  0.0000467  0.0046564
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -4.672e-05  4.304e-04  -0.109 0.914334
# Surivor_110  1.564e-02  4.253e-03   3.678 0.000989 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.001555 on 28 degrees of freedom
# Multiple R-squared:  0.3258,	Adjusted R-squared:  0.3017
# F-statistic: 13.53 on 1 and 28 DF,  p-value: 0.0009892

# %%
psr_C_melt$Genotype <- factor(psr_C_melt$Genotype, 
    levels = c("G_48", "G_62", "G_31", "G_8", "G_7","G_50"))

rick = ggplot(subset(psr_C_melt, ASV =="ASV2095"), aes(Surivor_110, Abundance)) +
geom_smooth(method='lm', color="black") +
geom_point(aes(color=Genotype), alpha=.4) + 
ylab("Relative Abundance") +
xlab("Survivorship Day 110") +
theme_classic() +
theme(legend.text =element_text(size=4)) +
theme(legend.title =element_text(size=4)) +
theme(axis.title.x = element_text(size = 5)) +
theme(axis.title.y = element_text(size = 5)) +
theme(axis.text.y = element_text(size =4)) +
theme(strip.text.x = element_text(size =4)) +
theme(strip.text.y = element_text(size =4)) +
theme(axis.text.x = element_text(size =4)) +
theme(strip.background = element_rect(
     fill="white", color="black", size=.5)) +
theme(legend.position = "none") +
facet_grid(.~Family)
rick

spiro = ggplot(subset(psr_C_melt, OTU =="2a9757272d74d9dceac1fc00fdf9933b"), aes(Surivor_110, Abundance)) +
geom_smooth(method='lm', color="black") +
geom_point(aes(color=Genotype) , alpha=.4) + 
ylab("Relative Abundance") +
xlab("Survivorship Day 110") +
#labs(color = "Gent") +
theme_classic() +
theme(legend.text =element_text(size=4)) +
theme(legend.title =element_text(size=4)) +
theme(axis.title.x = element_text(size = 5)) +
theme(axis.title.y = element_text(size = 5)) +
theme(axis.text.y = element_text(size =4)) +
theme(axis.text.x = element_text(size =4)) +
theme(strip.text.x = element_text(size =4)) +
theme(strip.text.y = element_text(size =4)) +
theme(strip.background = element_rect(
     fill="white", color="black", size=.5)) +
facet_grid(.~Family)

spiro
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
# plot without title
# plot without title

# %%
sig_sur_lm = ggarrange(rick, spiro, font.label = list(size = 7, color = "black"), labels=c("B","C"),
       common.legend = FALSE, widths = c(1, 1.3))
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'

# %%
ggarrange(ANCOM_nutri, sig_sur_lm, font.label = list(size = 7, color = "black"), labels=c("A"), nrow =2)
ggsave("/Users/stephanie.rosales/Documents/omics_projects/NutrientsAC16S/figures/fig6.svg",
     width = 5, height = 5, units = "in", dpi=300)
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Warning message:
# “Removed 246 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
GoodTaxa = c("09559efaa02f2d1000b20616d6ac4c10",
"27a90a5f695f8bccb3d1f1f03cbefe00",
"2a9757272d74d9dceac1fc00fdf9933b",
"cb94d54fbd46f4c7381e484a3ec93f1b",
"f5ab5cdbed22b56e99c06911e9efc981",
"abdc7d8d141a18a596ce062c646adb9e",
"cd7d8e0f6af7697da215d2340024323e",
"191a8648d18fce54066bdddd85bded65",
"9a30c1aa2ef737f5edfebebb81e895f4",
"f42edecaeb12b5bc32ce723fdb237685",
"3427e4c74f6ce96417c4f2c6295a0c03",
"118569d5769c8f5e135983de4f8b8de6",
"066b4bd4d22be208c993dad82aa18cfb",
"818ce170c2baa36a7c4abee269ea1387",
"bdc3e6ffc0239a40200bf7c3f088cd34",
"0172efa347740fe7d9cbd7dec793bd67",
"8cc15f7ae42da48a95d52fac614ae850",
"c1863e2053af386d9358bf1bfc985e0d",
"e56c8570ed61be7087d53108fcc59799",
"b710446d0c1f580a33d2b59c6534ad90",
"fe31e4219bf5c74ecf71ca12a84f35ef",
"1de3c07f672343d285de54373e837797",
"2553dd8562ebd5234f3b3102efe6ac4e",
"cfa2f6b05306ff94225768bafe0d483c",
"10c0c741818e4f0d057b110708f62d24",
"b8ebe7fb1dc5cc83be900438b75086b1",
"18544a615adb7bc24208a9413cf1bbe6",
"92d31f218032d2ebdcf3c632fe02bf48",
"26a78ca47dd81e8a4ad8e26bc78a2106",
"2e6aec58861742ffd02d43dab653608d",
"1b3166747999db8ad7967448f5771fb5",
"b18deeac05b63f464c321b122aff5ced",
"6f81a203d456b856111e39cc63155d7e",
"57c9ef626a29e130e303fb960ddbdc32",
"a83ec97a0b9d04af812c9115a2a834b6",
"4a566786f598b07e0ab6c5c834a46c8c",
"bcc8c2a040693c9809ec0e98bb6e56c8",
"f15ed42bebfc35cb7beb6b9c8674aaab",
"16c7f9c9d5e489a603191d407d51f4db",
"51bda5f388dc2d0d079f432e2bb64c4d"
)
allTaxa = taxa_names(psr)
allTaxa <- allTaxa[(allTaxa %in% GoodTaxa)]
sig_psr = prune_taxa(allTaxa, psr)
sig_psr =subset_samples(sig_psr, Treatment=="C")
sig_psr 

melt_ps_hh <- sig_psr %>%
psmelt()
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 40 taxa and 84 samples ]
# sample_data() Sample Data:       [ 84 samples by 60 sample variables ]
# tax_table()   Taxonomy Table:    [ 40 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 40 tips and 39 internal nodes ]

# %%
melt_ps_hh$Genotype <- factor(melt_ps_hh$Genotype, 
    levels = c("G_48", "G_62", "G_31", "G_8", "G_7","G_50"))


melt_ps_hh$Day <- factor(melt_ps_hh$Day,
   levels = c("75", "100", "111"))

nutr.labs <- c("Ambient", "NH4", "NH4 + P04")
names(nutr.labs) <- c("A", "N", "NP")

HH_PLOT = melt_ps_hh %>%
drop_na(Family) %>%
filter(Abundance > 0.03) %>%
#filter(former.id!="NTC") %>%
ggplot(
     
   aes(x = as.factor(Day), y=Abundance)) + 
#geom_bar(stat="identity", position="stack", aes(fill = Days)) +

geom_boxplot(outlier.size=0, fill="#4A6CAA") +
geom_point(aes(shape=Genotype), alpha=0.5) +
facet_grid(treatment~Order*Family*Genus, labeller = labeller(treatment =nutr.labs,
                                label_parsed) ) +
theme_classic() +
scale_y_continuous(trans = "log10") +
theme(legend.position = "bottom") +
guides(shape = guide_legend(nrow = 1)) +
theme(legend.text =element_text(size=4)) +
theme(legend.title = element_text(size=5)) +
theme(axis.title.x = element_text(size = 5)) +
theme(axis.title.y = element_text(size = 5)) +
theme(axis.text.x = element_text(size =4)) +
theme(axis.text.y = element_text(size =4)) +
#theme(axis.text.x=element_blank()) +
theme(axis.text.y = element_text(size =4)) +
scale_shape_manual("Genotype", values = c(15, 16, 17, 18, 8, 3)) +
#scale_shape_manual("Genotype", values = c(15, 18, 16, 8, 17, 3)) +
theme(strip.background = element_rect(
     fill="white", color="black", size=.5), strip.text = element_text(size = 3.3)) +
#scale_fill_manual(values=c("#4A6CAA", "#469B53" ,"#AA4A74")) 
ylab("Relative Abundance Log10") +
xlab("Day")

HH_PLOT
# Out:
# plot without title

# %%
GoodTaxa = c("09559efaa02f2d1000b20616d6ac4c10",
"16c7f9c9d5e489a603191d407d51f4db",
"2ca4167f4fc7c9da0cb4c7e9736588cc",
"bdc3e6ffc0239a40200bf7c3f088cd34",
"cb94d54fbd46f4c7381e484a3ec93f1b",
"f5ab5cdbed22b56e99c06911e9efc981",
"9a30c1aa2ef737f5edfebebb81e895f4",
"970424b92e1dc6cfc7abb159d01fb8d7",
"b8ebe7fb1dc5cc83be900438b75086b1",
"118569d5769c8f5e135983de4f8b8de6",
"d6a83f0bc2edfc999e010a189b3a7403",
"e853f94b05c9ff42fbe5a386387634ef"
)
allTaxa = taxa_names(psr)
allTaxa <- allTaxa[(allTaxa %in% GoodTaxa)]
sig_psr = prune_taxa(allTaxa, psr)

genets=c("G_48", "G_62")
sig_psr =subset_samples(sig_psr, Treatment=="N" & Genotype %in% genets )
sig_psr 

melt_ps_N <- sig_psr %>%
psmelt()
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 12 taxa and 26 samples ]
# sample_data() Sample Data:       [ 26 samples by 60 sample variables ]
# tax_table()   Taxonomy Table:    [ 12 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 12 tips and 11 internal nodes ]

# %%
melt_ps_N$Day <- factor(melt_ps_N$Day,
 levels = c("75", "100", "111"))

melt_ps_N$Genotype <- factor(melt_ps_N$Genotype, 
    levels = c("G_48", "G_62", "G_31", "G_8", "G_7","G_50"))

N_PLOT = melt_ps_N %>%

drop_na(Family) %>%
filter(Abundance > 0.00) %>%
#filter(former.id!="NTC") %>%
ggplot(
     
   aes(x = as.factor(Day), y=Abundance)) + 
#geom_bar(stat="identity", position="stack", aes(fill = Days)) +

#geom_boxplot(outlier.size=0, aes(fill=Treatment)) +
geom_boxplot(outlier.size=0, fill="#469B53") +
geom_point(aes(shape=Genotype), alpha=0.5) +
facet_grid(treatment~Order*Family*Genus, labeller = labeller(treatment =nutr.labs,
                                label_parsed) ) +
theme_classic() +
scale_y_continuous(trans = "log10") +
theme(legend.position = "bottom", legend.box = "horizontal") +
theme(legend.text =element_text(size=4)) +
theme(legend.title = element_text(size=5)) +
theme(axis.title.x = element_text(size = 5)) +
theme(axis.title.y = element_text(size = 5)) +
theme(axis.text.x = element_text(size =4)) +
theme(axis.text.y = element_text(size =4)) +
#theme(axis.text.x=element_blank()) +
theme(axis.text.y = element_text(size =4)) +
#scale_shape_manual("Genotype", values = c(15, 8)) +
scale_shape_manual("Genotype", values = c(15, 16, 17, 18, 8, 3)) +

theme(strip.background = element_rect(
     fill="white", color="black", size=.5), strip.text = element_text(size = 3.4)) +
#scale_fill_manual(name = "Treatment", labels=c(C=expression(paste(Ambient)),
 #                              N=expression(paste(NH^4)),
  #                             NP=expression(NH^4 + PO^4)),
   #              values=c("#469B53")) +
#scale_fill_manual(values=c("#4A6CAA", "#469B53" ,"#AA4A74")) 
ylab("Relative Abundance Log10") +
xlab("Day")
N_PLOT
# Out:
# plot without title

# %%
GoodTaxa = c("09559efaa02f2d1000b20616d6ac4c10",
"2a9757272d74d9dceac1fc00fdf9933b",
"abdc7d8d141a18a596ce062c646adb9e",
"cb94d54fbd46f4c7381e484a3ec93f1b",
"2553dd8562ebd5234f3b3102efe6ac4e",
"9a30c1aa2ef737f5edfebebb81e895f4",
"16c7f9c9d5e489a603191d407d51f4db",
"f5ab5cdbed22b56e99c06911e9efc981",
"0172efa347740fe7d9cbd7dec793bd67",
"26a78ca47dd81e8a4ad8e26bc78a2106",
"bcc8c2a040693c9809ec0e98bb6e56c8",
"18544a615adb7bc24208a9413cf1bbe6",
"bdc3e6ffc0239a40200bf7c3f088cd34",
"f15ed42bebfc35cb7beb6b9c8674aaab"
)
allTaxa = taxa_names(psr)
allTaxa <- allTaxa[(allTaxa %in% GoodTaxa)]
sig_psr = prune_taxa(allTaxa, psr)

genets=c("G_48", "G_62", "G_31")
sig_psr =subset_samples(sig_psr, Treatment=="NP" & Genotype %in% genets )
sig_psr 

melt_ps_NP <- sig_psr %>%
psmelt()
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 14 taxa and 41 samples ]
# sample_data() Sample Data:       [ 41 samples by 60 sample variables ]
# tax_table()   Taxonomy Table:    [ 14 taxa by 8 taxonomic ranks ]
# phy_tree()    Phylogenetic Tree: [ 14 tips and 13 internal nodes ]

# %%
melt_ps_NP$Day <- factor(melt_ps_NP$Day,
   levels = c("75", "100", "111"))

melt_ps_NP$Genotype <- factor(melt_ps_NP$Genotype, 
    levels = c("G_48", "G_62", "G_31", "G_8", "G_7","G_50"))

NP_PLOT = melt_ps_NP %>%

drop_na(Family) %>%
filter(Abundance > 0.00) %>%
#filter(former.id!="NTC") %>%
ggplot(
     
   aes(x = as.factor(Day), y=Abundance)) + 
#geom_bar(stat="identity", position="stack", aes(fill = Days)) +

#geom_boxplot(outlier.size=0, aes(fill=Treatment)) +
geom_boxplot(outlier.size=0, fill="#AA4A74") +
geom_point(aes(shape=Genotype), alpha=0.5) +
facet_grid(treatment~Order*Family*Genus, labeller = labeller(treatment =nutr.labs,
                                label_parsed) ) +
theme_classic() +
scale_y_continuous(trans = "log10") +
theme(legend.position = "bottom", legend.box = "horizontal") +
theme(legend.text =element_text(size=4)) +
theme(legend.title = element_text(size=5)) +
theme(axis.title.x = element_text(size = 5)) +
theme(axis.title.y = element_text(size = 5)) +
theme(axis.text.x = element_text(size =4)) +
theme(axis.text.y = element_text(size =4)) +
#theme(axis.text.x=element_blank()) +
theme(axis.text.y = element_text(size =4)) +
#scale_shape_manual("Genotype", values = c(15, 18, 8)) +
scale_shape_manual("Genotype", values = c(15, 16, 17, 18, 8, 3)) +
theme(strip.background = element_rect(
     fill="white", color="black", size=.5), strip.text = element_text(size = 3.4)) +
#scale_fill_manual(name = "Treatment", labels=c(C=expression(paste(Ambient)),
#                               N=expression(paste(NH^4)),
 #                              NP=expression(NH^4 + PO^4)),
 #                values=c("#AA4A74")) +
#scale_fill_manual(values=c("#4A6CAA", "#469B53" ,"#AA4A74")) 
ylab("Relative Abundance Log10") +
xlab("Day")
NP_PLOT
# Out:
# plot without title

# %%
ggarrange(HH_PLOT, N_PLOT, NP_PLOT, font.label = list(size = 7, color = "black"), labels=c("A", "B", "C"), nrow =3)
ggsave("/Users/stephanie.rosales/Documents/omics_projects/NutrientsAC16S/figures/fig_sup.svg",
        width = 7, height = 7, units = "in", dpi=300)
# Out:
# plot without title
